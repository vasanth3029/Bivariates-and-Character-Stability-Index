# %% [markdown]
#                 This Notebook explains how to use the bivariates function and to calculate CSI from its output

# %% [markdown]
# Importing the libraries

# %%
import pandas as pd
import numpy as np
from csi_bivar import info_val

# %% [markdown]
# For the purpose of this tutorial Im using a kaggle notebook which depicts a binary classification problem

# %%
df=pd.read_csv("bank.csv")
df.isna().sum()
# Out:
# age          0
# job          0
# marital      0
# education    0
# default      0
# balance      0
# housing      0
# loan         0
# contact      0
# duration     0
# campaign     0
# pdays        0
# previous     0
# poutcome     0
# y            0
# dtype: int64

# %%
df.y.replace({'yes':1,'no':0},inplace=True)

# %% [markdown]
# Splitting the data represent train and new Out-of-time.

# %%
train_data, oot_data = np.split(df.sample(frac=1, random_state=np.random.RandomState()), [int(0.7 * len(df))])

# %%
train_data.reset_index(inplace=True,drop= True)
oot_data.reset_index(inplace=True,drop= True)

# %%
train_data.head()
# Out:
#    age            job  marital  education default  balance housing loan  \
# 0   48  self-employed  married  secondary      no       91      no   no
# 1   70        retired  married    primary      no      579      no   no
# 2   35     technician   single   tertiary      no     2012     yes   no
# 3   31   entrepreneur   single   tertiary      no       38      no   no
# 4   29    blue-collar  married  secondary      no     1074      no   no
#
#     contact  duration  campaign  pdays  previous poutcome  y
# 0  cellular       136         8     -1         0  unknown  0
# 1  cellular        82         2    181         1  failure  0
# 2   unknown       413         2     -1         0  unknown  0
# 3  cellular       185         2     -1         0  unknown  0
# 4  cellular       153         1     -1         0  unknown  0

# %% [markdown]
# We need 4 parameters to call the bivariates function
# 1) y (string): Name of the Y variable
# 2) inp_fe (list): List containg the list of features for which the metrics should be calculated
# 3) in_df (DataFrame): Train DataFrame
# 4) out_df (DataFrame): Test/Out of time DataFrame

# %%
y="y"
inp_fe = list(train_data.columns)[:-1]
inp_fe
# Out:
# ['age',
#  'job',
#  'marital',
#  'education',
#  'default',
#  'balance',
#  'housing',
#  'loan',
#  'contact',
#  'duration',
#  'campaign',
#  'pdays',
#  'previous',
#  'poutcome']

# %%
indf,outdf = info_val(y, inp_fe, train_data.copy(), oot_data.copy())
# Out:
# age
# job
# marital
# education
# default
# balance
# housing
# loan
# contact
# duration
# campaign
# pdays
# previous
# poutcome

# %%
indf.head()
# Out:
#   keys_intime Levels_intime lower_intime upper_intime  total_intime  \
# 0         age  (17.0, 29.0]         17.0         29.0          3670
# 1         age  (29.0, 32.0]         29.0         32.0          4070
# 2         age  (32.0, 34.0]         32.0         34.0          2723
# 3         age  (34.0, 36.0]         34.0         36.0          2587
# 4         age  (36.0, 39.0]         36.0         39.0          3259
#
#    perc_in_feature_intime  Target_counts_intime  non_Target_counts_intime  \
# 0                0.115967                   632                      3038
# 1                0.128606                   451                      3619
# 2                0.086043                   281                      2442
# 3                0.081746                   286                      2301
# 4                0.102980                   326                      2933
#
#    Target_perc_current_level_intime  Target_percent_wrt_total_intime  \
# 0                          0.172207                         0.172066
# 1                          0.110811                         0.122788
# 2                          0.103195                         0.076504
# 3                          0.110553                         0.077866
# 4                          0.100031                         0.088756
#
#    Non_Target_perc_current_level_intime  Non_Target_percent_wrt_total_intime  \
# 0                              0.827793                             0.108601
# 1                              0.889189                             0.129370
# 2                              0.896805                             0.087295
# 3                              0.889447                             0.082255
# 4                              0.899969                             0.104847
#
#    WOE_intime  IV_intime
# 0   -0.460201   0.029207
# 1    0.052219   0.000344
# 2    0.131951   0.001424
# 3    0.054841   0.000241
# 4    0.166617   0.002681

# %%
'keys'                          - Variable
'Levels'                        - Level/bin of variable
'lower'                         - Lowest value in the bin for numerical variables
'upper'                         - Highest value in the bin for numerical variables 
'total'                         - Total number of rows/values
'perc_in_feature'               - % of rows for this particular level
'Target_counts'                 - Count of 1s in this level
'non_Target_counts'             - Count of 0s in this level
'Target_perc_current_level'     - % of 1s in this level out of total rows for the level
'Target_percent_wrt_total'      - % of 1s in this level out of total 1s ion data
'Non_Target_perc_current_level' - % of 0s in this level out of total rows for the level
'Non_Target_percent_wrt_total'  - % of 0s in this level out of total 0s in data
'WOE'                           - Weight of evidence
'IV'                            - Information value

# %% [markdown]
# # Character Stability Index

# %% [markdown]
# Once we have the bivariates with the percentages of Y at each level calculating CSI is straight forward

# %%
intime= indf[['keys_intime','Levels_intime','perc_in_feature_intime']]
outtime= outdf[['keys_outtime','Levels_outtime','perc_in_feature_outtime']]

csi=pd.merge(intime,outtime,left_on=['keys_intime','Levels_intime'],right_on=['keys_outtime','Levels_outtime'],how='left')
csi['csi']=(csi['perc_in_feature_intime']-csi['perc_in_feature_outtime'])*np.log((csi['perc_in_feature_intime']/csi['perc_in_feature_outtime']))

# %%
csi.head(10)
# Out:
#   keys_intime Levels_intime  perc_in_feature_intime keys_outtime  \
# 0         age  (17.0, 29.0]                0.115967          age
# 1         age  (29.0, 32.0]                0.128606          age
# 2         age  (32.0, 34.0]                0.086043          age
# 3         age  (34.0, 36.0]                0.081746          age
# 4         age  (36.0, 39.0]                0.102980          age
# 5         age  (39.0, 42.0]                0.087654          age
# 6         age  (42.0, 46.0]                0.103896          age
# 7         age  (46.0, 51.0]                0.110342          age
# 8         age  (51.0, 56.0]                0.093153          age
# 9         age  (56.0, 95.0]                0.089614          age
#
#   Levels_outtime  perc_in_feature_outtime       csi
# 0   (17.0, 29.0]                 0.118180  0.000042
# 1   (29.0, 32.0]                 0.130345  0.000023
# 2   (32.0, 34.0]                 0.086921  0.000009
# 3   (34.0, 36.0]                 0.082055  0.000001
# 4   (36.0, 39.0]                 0.102477  0.000002
# 5   (39.0, 42.0]                 0.082129  0.000360
# 6   (42.0, 46.0]                 0.103214  0.000004
# 7   (46.0, 51.0]                 0.107785  0.000060
# 8   (51.0, 56.0]                 0.092082  0.000012
# 9   (56.0, 95.0]                 0.094810  0.000293
